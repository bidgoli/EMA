# %% [markdown]
# # Animated Funtions
# ------------
#
# This notebook is devoted to animated plots. My main focus are on trigonometric functions which are inspired by polar coordinates. You may tune the function randomly and get surprise by the shape of the function.
#
# I've made up some interesting plots. I recommend to try it yourself. You need to download the notebook to make changes.

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
# %matplotlib notebook

th=np.arange(0,np.pi,0.01)

# %% [markdown]
# Here is the definition of the function. $\theta$ changes in the interval $(0,\pi)$ and the range of $t$, the time, can be tuned in the plotting cell.

# %%
def func(t):
    x=np.cos(t*th)*np.cos(th)
    y=np.sin(t*th)*np.sin(th)
    return x,y

# %%
def animate(c):
    x,y=func(c)
    ax.set_xlim(-1.1,1.1)
    ax.set_ylim(-1.1,1.1)
    line.set_xdata(x)
    line.set_ydata(y)

# %%
fig,ax=plt.subplots()
plt.title('($\cos(t a )\cos(a),\cos(ta)\sin(a)$)')
x,y=func(1)
line,=ax.plot(x,y)
ax.axis('off')



ani=FuncAnimation(fig,animate,np.arange(1,20,0.05),interval=2)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig,ax=plt.subplots()
plt.title('($\cos(2t a )\cos(a),\cos(ta)\sin(a)$)')
x,y=func(1)
line,=ax.plot(x,y)
ax.axis('off')



ani=FuncAnimation(fig,animate,np.arange(1,20,0.05),interval=2)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig,ax=plt.subplots()
plt.title('($\sin(t a )\sin(a),\cos(ta)\sin(a)$)')
x,y=func(1)
line,=ax.plot(x,y)
ax.axis('off')



ani=FuncAnimation(fig,animate,np.arange(1,20,0.05),interval=2)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig,ax=plt.subplots()
plt.title('($\cos(t+ a )\sin(a),\cos(ta)\sin(a)$)')
x,y=func(1)
line,=ax.plot(x,y)
ax.axis('off')



ani=FuncAnimation(fig,animate,np.arange(1,40,0.05),interval=2)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig,ax=plt.subplots()
plt.title('($\cos( a/t )\sin(a),\cos(ta)\sin(a)$)')
x,y=func(1)
line,=ax.plot(x,y)
ax.axis('off')



ani=FuncAnimation(fig,animate,np.arange(1,40,0.05),interval=2)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig,ax=plt.subplots()
plt.title('($\cos( at )\cos(a),\sin(ta)\sin(a)$)')
x,y=func(1)
line,=ax.plot(x,y)
ax.axis('off')



ani=FuncAnimation(fig,animate,np.arange(1,40,0.05),interval=2)
# Out:
# <img src="data:image/png;base64,..." width="640">
